# %%
# !git clone --depth=1 https://github.com/twintproject/twint.git
# !cd /content/twint && pip3 install . -r requirements.txt
# !pip install nest_asyncio
# import twint
# import nest_asyncio
# nest_asyncio.apply()
# import time
# import pandas as pd
# import os
# import re

# c = twint.Config()
# c.Limit = 5000
# c.Username = "collegemenfess"
# c.Since = "2022-12-05"
# c.Until = "2022-12-11"
# c.Store_csv = True
# c.Output = "scrap.csv"
# twint.run.Search(c)

# %% [markdown]
# # **Soal 1 : Scrap Data**

# %%
# Mengimport / Memanggil Library
import pandas as pd
import numpy as np

# %%
# Membaca Data
df = pd.read_csv('data/colle_scrap1.csv')
dataset = df[['id', 'username', 'created_at', 'tweet', 'replies_count', 'retweets_count', 'likes_count']]
dataset
# Out:
#                        id        username  \
# 0     1601728382596964352  collegemenfess
# 1     1601727590469111808  collegemenfess
# 2     1601726312796033024  collegemenfess
# 3     1601726216561491968  collegemenfess
# 4     1601725424429453313  collegemenfess
# ...                   ...             ...
# 4995  1600177056259637248  collegemenfess
# 4996  1600176140810739726  collegemenfess
# 4997  1600175194873946113  collegemenfess
# 4998  1600174663144857600  collegemenfess
# 4999  1600173968983351311  collegemenfess
#
#                                      created_at  \
# 0     2022-12-11 06:59:39 SE Asia Standard Time
# 1     2022-12-11 06:56:30 SE Asia Standard Time
# 2     2022-12-11 06:51:26 SE Asia Standard Time
# 3     2022-12-11 06:51:03 SE Asia Standard Time
# 4     2022-12-11 06:47:54 SE Asia Standard Time
# ...                                         ...
# 4995  2022-12-07 00:15:14 SE Asia Standard Time
# 4996  2022-12-07 00:11:36 SE Asia Standard Time
# ...

# %%
#Menghapus kolom yang tidak penting, karena data yang akan dideteksi hanya kolom tweet.
data = dataset.drop(['id', 'username', 'created_at', 'replies_count', 'retweets_count', 'likes_count'], axis=1)
#Memanggil 10 data teratas dari data tweet
data.head(50)
# Out:
#                                                 tweet
# 0        [cm] bisa ga sih skripsi tuh diilangin aja 🥲
# 1   [cm] tolong infonya ya makasih guys  https://t...
# 2   [cm] gaiss ada yg tau cara nyari jumlah atau d...
# 3   Besok aku praktik pertama kalinya di rumah sak...
# 4   ayooo bantu sender nyetok bahan2!! tia [cm]  h...
# 5   [cm] spek laptop gini buat anak arsi cukup gak...
# 6   [cm] kira2 sopan gak ya ngechat dosbing hari i...
# 7   Siapa yang pernah di posisi ini, ada solusi ga...
# 8   [Cm] ada mahasiswa magister akuntansi/ekonomi ...
# 9   [cm] Gais kampus pendidikan yg terkenal di Ind...
# 10  [cm] Udah dikasih minggu tenang ujung2nya bela...
# 11  [Cm] Kegiatan di kampusku mulai dari jam 3 don...
# 12  [cm] sender baru aja nyelesain proposal sender...
# 13  [CM] Temen-temen dari UKSW ada yang udah bangu...
# 14  [cm] ges aku mau bikin bagan gitu di word cuma...
# 15  [Cm] Mau nanya kalau bab 1 variabelnya bahas m...
# ...

# %% [markdown]
# # **Preprocessing Clean Data**
#
# Dalam preprocessing data terdapat beberapa tahap antara lain
#
# *   **Case Folding** : Melakukan proses case folding dengan fungsi lower() pada class Series.str library Pandas
# *   **Tokenizing** : Proses number removal, whitecase removal, puntuation removal dan word_tokenize() untuk memecah string kedalam tokens. Pandas Dataframe atau Series mampu menjalankan function external untuk di terapkan pada kolom atau baris dengan menggunakan fungsi .apply()
# *   **Filtering (Stopword Removal)** : Menggunakan library NLTK untuk filtering terhadap Dataframe dengan bahasa english. Menambahkan list stopword dengan menggunakan fungsi .extend() terhadap list_stopword , penggunaan fungsi .set() bermanfaat untuk membuat iterable list menjadi sequence iterable element. Hasilnya kita dapat mempercepat proses pengecekan apakan sebuah token terdapat pada list_stopword atau tidak (if token not in list_stopword)
# *   **Stemming**: Normalization digunakan untuk menyeragamkan term yang memiliki makna sama namun penulisanya berbeda, bisa diakibatkan kesalahan penulisan, penyingkatan kata, ataupun “bahasa gaul”.

# %%
#Mengimport beberapa Library yang akan dipakai untuk mengolah data tweet diatas.
import datetime as dt
import re
import nltk
import string
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
from Sastrawi.Stemmer.StemmerFactory import StemmerFactory
from Sastrawi.StopWordRemover.StopWordRemoverFactory import StopWordRemoverFactory
from wordcloud import WordCloud

from keras.preprocessing.text import Tokenizer
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from keras.models import Sequential
from keras.layers import Embedding, Dense, Dropout, LSTM
from keras.optimizers import Adam, RMSprop, SGD
from keras.callbacks import EarlyStopping
from keras.wrappers.scikit_learn import KerasClassifier
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import confusion_matrix

# %%
# Mendownload stopword
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Asus\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
#fungsi untuk menghapus emoji
def remove_emoji(string):
    emoji_pattern = re.compile("["
                           u"\U0001F600-\U0001F64F"  # emoticons
                           u"\U0001F300-\U0001F5FF"  # symbols & pictographs
                           u"\U0001F680-\U0001F6FF"  # transport & map symbols
                           u"\U0001F1E0-\U0001F1FF"  # flags (iOS)
                           u"\U00002702-\U000027B0"
                           u"\U000024C2-\U0001F251"
                           "]+", flags=re.UNICODE)
    return emoji_pattern.sub(r'', string)

data["tweet"] = data["tweet"].apply(remove_emoji)

# %%
stemmer = nltk.SnowballStemmer("english")
from nltk.corpus import stopwords
import string
stopword=set(stopwords.words('indonesian'))

def clean(text):
    text = str(text).lower() # Converting all the characters in a text into lower case
    text = re.sub(r'@[A-Za-z0-9]+', '', text) # remove mentions
    text = re.sub(r'#[A-Za-z0-9]+', '', text) # remove hashtag
    text = re.sub(r'RT[\s]', '', text) # remove RT
    text = re.sub(r"http\S+", '', text) # remove link
    text = re.sub(r'[0-9]+', '', text) # remove numbers
    text = re.sub('\[.*?\]', '', text)
    text = re.sub('<.*?>+', '', text)
    text = re.sub('[%s]' % re.escape(string.punctuation), '', text) # remove all punctuations(tandabaca)
    text = re.sub('\n', '', text) # replace new line into space
    text = text.strip(' ') # remove characters space from both left and right text
    text = re.sub('\w*\d\w*', '', text)
    text = [word for word in text.split(' ') if word not in stopword] # Remove stopwords in a text
    text=" ".join(text)
    text = [stemmer.stem(word) for word in text.split(' ')] # Reducing a word to its word stem that affixes to suffixes and prefixes or to the roots of words
    text=" ".join(text)
    return text
data["tweet"] = data["tweet"].apply(clean)

# %%
data.head(50)
# Out:
#                                                 tweet
# 0                  ga sih skripsi tuh diilangin aja 🥲
# 1                       tolong infonya ya makasih guy
# 2   gaiss yg tau nyari daftar perusahaan manufaktu...
# 3   besok praktik kalinya rumah sakit  jantung deg...
# 4                 ayooo bantu sender nyetok bahan tia
# 5                  spek laptop gini anak arsi gak tia
# 6   sopan gak ya ngechat dosb konsultasi skripsi b...
# 7                          posisi solusi gak ya kira²
# 8   mahasiswa magist akuntansiekonomi gaaa especi ...
# 9   gai kampus pendidikan yg terken indonesia upi ...
# 10  udah dikasih minggu tenang ujungnya belajar ua...
# 11                           kegiatan kampusku jam  🫠
# 12  sender aja nyelesain propos sender jd degan kr...
# 13  tementemen uksw udah bangun tolong download re...
# 14  ges bikin bagan gitu word bingung biar tepinya...
# 15  nanya bab  variabelnya baha mahasiswa pembukaa...
# ...

# %% [markdown]
# # **Soal 2 : Clustering**
#
# Pengelompokan data ke dalam beberapa kategori atau cluster, yaitu
# komentar positif, netral, dan negatif.

# %%
#Pada tahap ini kita menggunakan SentimentIntensityAnalyzer yang dimana SentimentIntensityAnalyzer ini adalah proses 'secara komputasi' menentukan apakah sebuah tulisan itu positif, negatif atau netral. 
from nltk.sentiment.vader import SentimentIntensityAnalyzer
nltk.download('vader_lexicon')
analyser = SentimentIntensityAnalyzer()
scores = [analyser.polarity_scores(x) for x in data['tweet']]
print(scores)
data['Compound score'] = [x['compound'] for x in scores]
# Out:
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     C:\Users\Asus\AppData\Roaming\nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# ...

# %%
data.head()
# Out:
#                                                tweet  Compound score
# 0                 ga sih skripsi tuh diilangin aja 🥲          0.0000
# 1                      tolong infonya ya makasih guy          0.0000
# 2  gaiss yg tau nyari daftar perusahaan manufaktu...          0.5106
# 3  besok praktik kalinya rumah sakit  jantung deg...          0.0000
# 4                ayooo bantu sender nyetok bahan tia          0.5106

# %%
data.loc[data['Compound score'] < 0 , 'Sentiments'] = 'Negatif'
data.loc[data['Compound score'] == 0 , 'Sentiments'] = 'Netral'
data.loc[data['Compound score'] >  0 , 'Sentiments'] = 'Positif'

data.head(100)
# Out:
#                                                 tweet  Compound score  \
# 0                  ga sih skripsi tuh diilangin aja 🥲          0.0000
# 1                       tolong infonya ya makasih guy          0.0000
# 2   gaiss yg tau nyari daftar perusahaan manufaktu...          0.5106
# 3   besok praktik kalinya rumah sakit  jantung deg...          0.0000
# 4                 ayooo bantu sender nyetok bahan tia          0.5106
# ..                                                ...             ...
# 95  misiii adaa yg ngeprelov kalkul scientif csio ...          0.0000
# 96  temen cek plagiat turnitin persen nya ngga ya ...          0.0000
# 97  yg organisasi ga si nunggak byr kas trus samp ...          0.0000
# 98  gai kalo nyatet materi kuliah aja niat bgt lia...          0.0000
# 99  sidang skripsi semengerikan saudara saudara se...         -0.0772
#
#    Sentiments
# 0      Netral
# 1      Netral
# 2     Positif
# 3      Netral
# 4     Positif
# ..        ...
# 95     Netral
# ...

# %% [markdown]
# # **Soal 3 : Labeling**
#
# Label merupakan hasil dari pengelompokan melalui clustering

# %%
from sklearn import preprocessing
X = data['tweet'].values
lbl_enc = preprocessing.LabelEncoder()
y = lbl_enc.fit_transform(data.Sentiments.values)

# %%
data['label'] = y

# %%
data.head(100)
# Out:
#                                                 tweet  Compound score  \
# 0                  ga sih skripsi tuh diilangin aja 🥲          0.0000
# 1                       tolong infonya ya makasih guy          0.0000
# 2   gaiss yg tau nyari daftar perusahaan manufaktu...          0.5106
# 3   besok praktik kalinya rumah sakit  jantung deg...          0.0000
# 4                 ayooo bantu sender nyetok bahan tia          0.5106
# ..                                                ...             ...
# 95  misiii adaa yg ngeprelov kalkul scientif csio ...          0.0000
# 96  temen cek plagiat turnitin persen nya ngga ya ...          0.0000
# 97  yg organisasi ga si nunggak byr kas trus samp ...          0.0000
# 98  gai kalo nyatet materi kuliah aja niat bgt lia...          0.0000
# 99  sidang skripsi semengerikan saudara saudara se...         -0.0772
#
#    Sentiments  label
# 0      Netral      1
# 1      Netral      1
# 2     Positif      2
# 3      Netral      1
# ...

# %% [markdown]
# ### Pemilahan data training dan testing yang sesuai dan proporsional dari data

# %%
#import package 
from sklearn.model_selection import train_test_split
# Split data training dan testing
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=10)
print(X_train.shape, y_train.shape)
print(X_test.shape, y_test.shape)
# Out:
# (4000,) (4000,)
# (1000,) (1000,)

# %% [markdown]
# ### Extracting with TF-IDF

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
#Extracting TF-IDF parameters
tfidf = TfidfVectorizer(max_features=1000, analyzer='word', ngram_range=(1,3))
x_train_tfidf = tfidf.fit_transform(X_train)
x_val_tfidf = tfidf.fit_transform(X_test)

# %% [markdown]
# # **Soal 4: Classification**
#
# Pada proses klasifikasi ini menggunakan metode algoritma yaitu yang pernah dipelajari dalam matakuliah Machine Learning

# %% [markdown]
# MODEL MULTINOMIAL

# %%
from sklearn.naive_bayes import MultinomialNB 
nb = MultinomialNB()
nb.fit(x_train_tfidf, y_train)
y_pred = nb.predict(x_val_tfidf)
print('naive bayes tfidf accuracy %s' % accuracy_score(y_pred, y_test))
# Out:
# naive bayes tfidf accuracy 0.772

# %% [markdown]
# LINEAR SVM

# %%
# Model 2: Linear SVM
from sklearn.linear_model import SGDClassifier
lsvm = SGDClassifier(alpha=0.001, random_state=5, max_iter=15, tol=None)
lsvm.fit(x_train_tfidf, y_train)
y_pred = lsvm.predict(x_val_tfidf)
print(accuracy_score(y_pred, y_test))
# Out:
# 0.785

# %% [markdown]
# LOGISTIC REGRESSION

# %%
from sklearn.linear_model import LogisticRegression
# Model 3: Logistic Regression
logreg = LogisticRegression(C=1)
logreg.fit(x_train_tfidf, y_train)
y_pred = logreg.predict(x_val_tfidf)
print(accuracy_score(y_pred, y_test))
# Out:
# 0.782

# %% [markdown]
# # **Soal 5 : Predict**
#
# Prediksi sentimen data twitter yang baru (500 twit). Evaluasi akurasi dari model
# berdasarkan data baru

# %%
# Membaca Data
df2 = pd.read_csv('data\other_data2.csv')
other = df2[['id', 'username', 'created_at', 'tweet', 'replies_count', 'retweets_count', 'likes_count']]
other
# Out:
#                       id        username               created_at  \
# 0    1604989828114051072  collegemenfess  2022-12-19 23:59:28 UTC
# 1    1604989405382729728  collegemenfess  2022-12-19 23:57:48 UTC
# 2    1604988906289606657  collegemenfess  2022-12-19 23:55:49 UTC
# 3    1604987594282262528  collegemenfess  2022-12-19 23:50:36 UTC
# 4    1604987464057499648  collegemenfess  2022-12-19 23:50:05 UTC
# ..                   ...             ...                      ...
# 495  1604805271917776896  collegemenfess  2022-12-19 11:46:07 UTC
# 496  1604805205845233664  collegemenfess  2022-12-19 11:45:51 UTC
# 497  1604805184621723648  collegemenfess  2022-12-19 11:45:46 UTC
# 498  1604805177722429445  collegemenfess  2022-12-19 11:45:44 UTC
# 499  1604805085577744386  collegemenfess  2022-12-19 11:45:22 UTC
#
#                                                  tweet  replies_count  \
# 0    [cm] iri banget liat temenku yang dospem nya b...              4
# ...

# %%
#Menghapus kolom yang yg penting, karena data yang akan dideteksi hanya kolom tweet.
other2 = other.drop(['id', 'username', 'created_at', 'replies_count', 'retweets_count', 'likes_count'], axis=1)
#Memanggil 10 data teratas dari data tweet
other2.head()
# Out:
#                                                tweet
# 0  [cm] iri banget liat temenku yang dospem nya b...
# 1  [Cm] bingung bangett pilih konsentrasi apa ya?...
# 2  Kalian yg kuliah kelas malem/kelas karyawan, r...
# 3  Cara nolak ngasih jawaban kita ke anak gg deke...
# 4  kalian tim percaya atau ngga kalo resume kita ...

# %%
#Mengubah nama kolom tweet dengan nama "text" agar variablenya tidak sama dengan variable diatas
other2.rename(columns = {"tweet": "text"}, inplace=True)
other2
# Out:
#                                                   text
# 0    [cm] iri banget liat temenku yang dospem nya b...
# 1    [Cm] bingung bangett pilih konsentrasi apa ya?...
# 2    Kalian yg kuliah kelas malem/kelas karyawan, r...
# 3    Cara nolak ngasih jawaban kita ke anak gg deke...
# 4    kalian tim percaya atau ngga kalo resume kita ...
# ..                                                 ...
# 495  [cm] SPILL MOTTO SKRIPSI KALIAN DONG😭😭 Mau Sem...
# 496  [CM] GAISSS HELPPPP!!! Air kost ku kuning, uda...
# 497  [cm] mohon bantuannya yang paham yaa😔  https:/...
# 498  [CM] gais tolong rekomendasiin website buat tr...
# 499  [cm] kamu join suatu organisasi dan disodorin ...
#
# [500 rows x 1 columns]

# %% [markdown]
# ### CLEAN DATA
#
# Melakukan Pembersihan Data dengan cara yang sama.

# %%
from keras import preprocessing

# %%
#Mengimport beberapa Library yang akan dipakai untuk mengolah data tweet diatas.
import datetime as dt
import re
import nltk
import string

from tensorflow.keras.preprocessing.text import Tokenizer
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
from Sastrawi.Stemmer.StemmerFactory import StemmerFactory
from Sastrawi.StopWordRemover.StopWordRemoverFactory import StopWordRemoverFactory
from wordcloud import WordCloud
from keras.preprocessing.text import Tokenizer

from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from keras.models import Sequential
from keras.layers import Embedding, Dense, Dropout, LSTM
from keras.optimizers import Adam, RMSprop, SGD
from keras.callbacks import EarlyStopping
from keras.wrappers.scikit_learn import KerasClassifier
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import confusion_matrix

# %%
#fungsi untuk menghapus emoji
def remove_emoji(string):
    emoji_pattern = re.compile("["
                           u"\U0001F600-\U0001F64F"  # emoticons
                           u"\U0001F300-\U0001F5FF"  # symbols & pictographs
                           u"\U0001F680-\U0001F6FF"  # transport & map symbols
                           u"\U0001F1E0-\U0001F1FF"  # flags (iOS)
                           u"\U00002702-\U000027B0"
                           u"\U000024C2-\U0001F251"
                           "]+", flags=re.UNICODE)
    return emoji_pattern.sub(r'', string)

other2["text"] = other2["text"].apply(remove_emoji)

# %%
stemmer = nltk.SnowballStemmer("english")
from nltk.corpus import stopwords
import string
stopword=set(stopwords.words('indonesian'))

def clean(text):
    text = str(text).lower() # Converting all the characters in a text into lower case
    text = re.sub(r'@[A-Za-z0-9]+', '', text) # remove mentions
    text = re.sub(r'#[A-Za-z0-9]+', '', text) # remove hashtag
    text = re.sub(r'RT[\s]', '', text) # remove RT
    text = re.sub(r"http\S+", '', text) # remove link
    text = re.sub(r'[0-9]+', '', text) # remove numbers
    text = re.sub('\[.*?\]', '', text)
    text = re.sub('<.*?>+', '', text)
    text = re.sub('[%s]' % re.escape(string.punctuation), '', text) # remove all punctuations
    text = re.sub('\n', '', text) # replace new line into space
    text = text.strip(' ') # remove characters space from both left and right text
    text = re.sub('\w*\d\w*', '', text)
    text = [word for word in text.split(' ') if word not in stopword] # Remove stopwors in a text
    text=" ".join(text)
    text = [stemmer.stem(word) for word in text.split(' ')] # Reducing a word to its word stem that affixes to suffixes and prefixes or to the roots of words
    text=" ".join(text)
    return text
other2["text"] = other2["text"].apply(clean)

# %%
other2.head(100)
# Out:
#                                                  text
# 0   iri banget liat temenku dospem nya diajak kerj...
# 1   bingung bangett pilih konsentrasi ya  minat ma...
# 2   yg kuliah kela malemkela karyawan review dongg...
# 3   nolak ngasih anak gg deket gimana ya nyesel ka...
# 4   tim percaya ngga kalo resum dibaca dosen  send...
# ..                                                ...
# 95              lu udah kkn ga kalo suruh ngulang kkn
# 96  laptop stress tugasjangan lupa makan istirahat ya
# 97  guy nyambi kerja pemasukan ga ngeganggu kewaji...
# 98              jam segini melek ngapain guy bobo guy
# 99     kkn kebagian sekretari tugasnya ngaoain aja ya
#
# [100 rows x 1 columns]

# %% [markdown]
# # **Clustering**
#
# Pengelompokan data ke dalam beberapa kategori atau cluster, yaitu
# komentar positif, netral, dan negatif.

# %%
#Pada tahap ini kita menggunakan SentimentIntensityAnalyzer yang dimana SentimentIntensityAnalyzer ini adalah proses 'secara komputasi' menentukan apakah sebuah tulisan itu positif, negatif atau netral. 
from nltk.sentiment.vader import SentimentIntensityAnalyzer
nltk.download('vader_lexicon')
analyser = SentimentIntensityAnalyzer()
scores = [analyser.polarity_scores(x) for x in other2['text']]
print(scores)
other2['compound score'] = [x['compound'] for x in scores]
# Out:
# [{'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}, {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}, {'neg': 0.0, 'neu': 0.89, 'pos': 0.11, 'compound': 0.2732}, {'neg': 0.0, 'neu': 0.855, 'pos': 0.145, 'compound': 0.296}, {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}, {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}, {'neg': 0.0, 'neu': 0.769, 'pos': 0.231, 'compound': 0.5106}, {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}, {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}, {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}, {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}, {'neg': 0.0, 'neu': 0.902, 'pos': 0.098, 'compound': 0.3612}, {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}, {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}, {'neg': 0.0, 'neu': 0.864, 'pos': 0.136, 'compound': 0.296}, {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}, {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}, {'neg': 0.0, 'neu': 0.82, 'pos'
# ...

# %%
other2.head()
# Out:
#                                                 text  compound score
# 0  iri banget liat temenku dospem nya diajak kerj...          0.0000
# 1  bingung bangett pilih konsentrasi ya  minat ma...          0.0000
# 2  yg kuliah kela malemkela karyawan review dongg...          0.2732
# 3  nolak ngasih anak gg deket gimana ya nyesel ka...          0.2960
# 4  tim percaya ngga kalo resum dibaca dosen  send...          0.0000

# %%
other2.loc[other2['compound score'] < 0 , 'sentiments'] = 'Negatif'
other2.loc[other2['compound score'] == 0 , 'sentiments'] = 'Netral'
other2.loc[other2['compound score'] >  0 , 'sentiments'] = 'Positif'

other2.head(100)
# Out:
#                                                  text  compound score  \
# 0   iri banget liat temenku dospem nya diajak kerj...          0.0000
# 1   bingung bangett pilih konsentrasi ya  minat ma...          0.0000
# 2   yg kuliah kela malemkela karyawan review dongg...          0.2732
# 3   nolak ngasih anak gg deket gimana ya nyesel ka...          0.2960
# 4   tim percaya ngga kalo resum dibaca dosen  send...          0.0000
# ..                                                ...             ...
# 95              lu udah kkn ga kalo suruh ngulang kkn          0.0000
# 96  laptop stress tugasjangan lupa makan istirahat ya         -0.4215
# 97  guy nyambi kerja pemasukan ga ngeganggu kewaji...          0.0000
# 98              jam segini melek ngapain guy bobo guy          0.0000
# 99     kkn kebagian sekretari tugasnya ngaoain aja ya          0.0000
#
#    sentiments
# 0      Netral
# 1      Netral
# 2     Positif
# 3     Positif
# 4      Netral
# ..        ...
# 95     Netral
# ...

# %% [markdown]
# # **Labeling**
#
# Label merupakan hasil dari pengelompokan melalui clustering

# %%
from sklearn import preprocessing
X1 = other2['text'].values
lbl_enc = preprocessing.LabelEncoder()
y1 = lbl_enc.fit_transform(other2.sentiments.values)
other2['label'] = y1

# %%
other2.head(100)
# Out:
#                                                  text  compound score  \
# 0   iri banget liat temenku dospem nya diajak kerj...          0.0000
# 1   bingung bangett pilih konsentrasi ya  minat ma...          0.0000
# 2   yg kuliah kela malemkela karyawan review dongg...          0.2732
# 3   nolak ngasih anak gg deket gimana ya nyesel ka...          0.2960
# 4   tim percaya ngga kalo resum dibaca dosen  send...          0.0000
# ..                                                ...             ...
# 95              lu udah kkn ga kalo suruh ngulang kkn          0.0000
# 96  laptop stress tugasjangan lupa makan istirahat ya         -0.4215
# 97  guy nyambi kerja pemasukan ga ngeganggu kewaji...          0.0000
# 98              jam segini melek ngapain guy bobo guy          0.0000
# 99     kkn kebagian sekretari tugasnya ngaoain aja ya          0.0000
#
#    sentiments  label
# 0      Netral      1
# 1      Netral      1
# 2     Positif      2
# 3     Positif      2
# ...

# %% [markdown]
#  ### PREDICT DATA TWEET (500)

# %%
y_pred_otherData = nb.predict(other2['text'])
other2['Result Prediction'] = y_pred_otherData

polarity_decode = {0 : 'Negative', 1 : 'Neutral', 2 : 'Positive'}
other2['Result Prediction'] = other2['Result Prediction'].map(polarity_decode)
other2
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-58-47ed80db52b0> in <module>
# ----> 1 y_pred_otherData = nb.predict(other2['text'])
#       2 other2['Result Prediction'] = y_pred_otherData
#       3
#       4 polarity_decode = {0 : 'Negative', 1 : 'Neutral', 2 : 'Positive'}
#       5 other2['Result Prediction'] = other2['Result Prediction'].map(polarity_decode)
#
# c:\ProgramData\Anaconda3\lib\site-packages\sklearn\naive_bayes.py in predict(self, X)
#      72         """
#      73         check_is_fitted(self)
# ---> 74         X = self._check_X(X)
#      75         jll = self._joint_log_likelihood(X)
#      76         return self.classes_[np.argmax(jll, axis=1)]
#
# c:\ProgramData\Anaconda3\lib\site-packages\sklearn\naive_bayes.py in _check_X(self, X)
#     472
#     473     def _check_X(self, X):
# --> 474         return check_array(X, accept_sparse='csr')
# ...

# %% [markdown]
# ### Dikarenakan Tidak bisa, maka tugas nomer 5 di split agar bisa di predict :)

# %% [markdown]
# ## Pemilahan data training dan testing yang sesuai dan proporsional

# %%
#import package 
from sklearn.model_selection import train_test_split
# Split data training dan testing
X1_train, X1_test, y1_train, y1_test = train_test_split(X1, y1, test_size=0.2, random_state=10)
print(X1_train.shape, y1_train.shape)
print(X1_test.shape, y1_test.shape)
# Out:
# (400,) (400,)
# (100,) (100,)

# %% [markdown]
# ### EKSTRASI FITUR

# %%
#Extracting TF-IDF parameters
tfidf1 = TfidfVectorizer(max_features=1000, analyzer='word', ngram_range=(1,3))
x_train_tfidf1 = tfidf.fit_transform(X1_train)
x_val_tfidf1 = tfidf.fit_transform(X1_test)

# %% [markdown]
# # **Classification**
#
# Pada proses klasifikasi ini menggunakan metode algoritma yang pernah dipelajari dalam matakuliah Machine Learning

# %% [markdown]
# MULTINOMIAL-NAIVEBAYES

# %%
from sklearn.naive_bayes import MultinomialNB 
nb = MultinomialNB()
nb.fit(x_train_tfidf1, y1_train)
y_pred1 = nb.predict(x_val_tfidf1)
print('naive bayes tfidf accuracy %s' % accuracy_score(y_pred1, y1_test))
# Out:
# naive bayes tfidf accuracy 0.82

# %% [markdown]
# ### Linear SVM

# %%
# Model 2: Linear SVM
from sklearn.linear_model import SGDClassifier
lsvm = SGDClassifier(alpha=0.001, random_state=5, max_iter=15, tol=None)
lsvm.fit(x_train_tfidf1, y1_train)
y_pred1 = lsvm.predict(x_val_tfidf1)
print('Linear SVM accuracy %s ' % accuracy_score(y_pred1, y1_test))
# Out:
# Linear SVM accuracy 0.75

# %% [markdown]
# ### Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression
# Model 3: Logistic Regression
logreg = LogisticRegression(C=1)
logreg.fit(x_train_tfidf1, y1_train)
y_pred1 = logreg.predict(x_val_tfidf1)
print('Logistic Regression %s ' %accuracy_score(y_pred1, y1_test))
# Out:
# Logistic Regression 0.82

# %% [markdown]
# ### Decision Tree

# %%
from sklearn.tree import DecisionTreeClassifier

# Memanggil method Decision, yang secara default, DecisionTreeClassifier dari scikit-learn  menggunakan nilai "Gini" untuk kriterianya.
dt = DecisionTreeClassifier()
#fit model
dt.fit(x_train_tfidf1, y1_train)

from sklearn.metrics import accuracy_score
# Memprediksi test 
y_pred1 = dt.predict(x_val_tfidf1)

#  menghitung akurasi
acc = accuracy_score(y1_test, y_pred1)
print(f"Test set accuracy: {acc}")
# Out:
# Test set accuracy: 0.65
